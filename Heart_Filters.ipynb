# %%
import librosa
import librosa.display

y, sr = librosa.load('normal.wav')
librosa.feature.chroma_stft(y=y, sr=sr)
# Out:
# array([[0.6286964 , 0.7576496 , 0.5948907 , ..., 0.68972415, 0.9691771 ,
#         0.69943386],
#        [0.74075174, 1.        , 0.5912805 , ..., 0.608284  , 1.        ,
#         0.9037707 ],
#        [0.72552514, 0.9802233 , 0.5637783 , ..., 0.5588815 , 0.94476163,
#         0.9257437 ],
#        ...,
#        [0.67336094, 0.712683  , 0.8318822 , ..., 1.        , 0.8758941 ,
#         1.        ],
#        [0.64348394, 0.8419223 , 1.        , ..., 0.8208696 , 0.9681241 ,
#         0.88625956],
#        [0.65583795, 0.7954154 , 0.77158254, ..., 0.7180388 , 0.9056944 ,
#         0.65635014]], dtype=float32)

# %%
import numpy as np
S = np.abs(librosa.stft(y))
chroma = librosa.feature.chroma_stft(S=S, sr=sr)

# %%
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(10, 4))
librosa.display.specshow(chroma, y_axis='chroma', x_axis='time')
plt.colorbar()
plt.title('Chromagram')
plt.tight_layout()

# %%
import librosa
import librosa.display

y, sr = librosa.load('abnormal.wav')
librosa.feature.chroma_stft(y=y, sr=sr)

import numpy as np
S = np.abs(librosa.stft(y))
chroma = librosa.feature.chroma_stft(S=S, sr=sr)

np.abs(librosa.stft(y, n_fft=4096))**2
chroma = librosa.feature.chroma_stft(S=S, sr=sr)

import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(10, 4))
librosa.display.specshow(chroma, y_axis='chroma', x_axis='time')
plt.colorbar()
plt.title('Chromagram')
plt.tight_layout()

# %%
y, sr = librosa.load('normal.wav')
chroma_cens = librosa.feature.chroma_cens(y=y, sr=sr)
chroma_cq = librosa.feature.chroma_cqt(y=y, sr=sr)
chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.subplot(2,1,1)
librosa.display.specshow(chroma_cq, y_axis='chroma')
plt.title('chroma_cq')
plt.colorbar()

# %%
plt.subplot(2,1,2)
librosa.display.specshow(chroma_cens, y_axis='chroma', x_axis='time')
plt.title('chroma_cens')
plt.colorbar()
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.subplot(2,1,1)
librosa.display.specshow(chroma_stft, y_axis='chroma')
plt.title('chroma_stft')
plt.colorbar()

# %%
plt.subplot(2,1,2)
librosa.display.specshow(chroma_cq, y_axis='chroma', x_axis='time')
plt.title('chroma_cqt')
plt.colorbar()
plt.tight_layout()

# %%
y, sr = librosa.load('abnormal.wav')
chroma_cens = librosa.feature.chroma_cens(y=y, sr=sr)
chroma_cq = librosa.feature.chroma_cqt(y=y, sr=sr)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.subplot(2,1,1)
librosa.display.specshow(chroma_cq, y_axis='chroma')
plt.title('chroma_cq')
plt.colorbar()

# %%
plt.subplot(2,1,2)
librosa.display.specshow(chroma_cens, y_axis='chroma', x_axis='time')
plt.title('chroma_cens')
plt.colorbar()
plt.tight_layout()

# %%
y, sr = librosa.load('abnormal.wav')
chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr,n_chroma=12, n_fft=4096)
chroma_cq = librosa.feature.chroma_cqt(y=y, sr=sr)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.subplot(2,1,1)
librosa.display.specshow(chroma_stft, y_axis='chroma')
plt.title('chroma_stft')
plt.colorbar()

# %%
plt.subplot(2,1,2)
librosa.display.specshow(chroma_cq, y_axis='chroma', x_axis='time')
plt.title('chroma_cqt')
plt.colorbar()
plt.tight_layout()
